# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
from sklearn import preprocessing

data = pd.read_csv("pulsar_stars.csv")

data = data.drop(data.columns[8], 1);
data.head()
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# 1                            -0.515088                   1.677258
# 2                             1.051164                   3.121237
# 3                            -0.636238                   3.642977
# 4                             1.123492                   1.178930
#
#     Standard deviation of the DM-SNR curve  \
# 0                                19.110426
# 1                                14.860146
# 2                                21.744669
# 3                                20.959280
# 4                                11.468720
#
#     Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve
# 0                              7.975532                      74.242225
# 1                             10.576487                     127.393580
# 2                              7.735822                      63.171909
# 3                              6.896499                      53.593661
# 4                             14.269573                     252.567306

# %%
data.iloc[5043]
print('min')
print(np.min(data.iloc[:,1].values))
print('max')
print(np.max(data.iloc[:,1].values))
print(5.8125/173625.0)
# Out:
# min
# 24.77204176
# max
# 32375.0
# 3.347732181425486e-05

# %%
plt.matshow(data.corr())

# %%
data.corr()
# Out:
#                                                 Mean of the integrated profile  \
#  Mean of the integrated profile                                       1.000000
#  Standard deviation of the integrated profile                        -0.000597
#  Excess kurtosis of the integrated profile                           -0.039351
#  Skewness of the integrated profile                                  -0.031990
#  Mean of the DM-SNR curve                                            -0.013739
#  Standard deviation of the DM-SNR curve                              -0.010734
#  Excess kurtosis of the DM-SNR curve                                  0.009607
#  Skewness of the DM-SNR curve                                         0.008601
#
#                                                 Standard deviation of the integrated profile  \
#  Mean of the integrated profile                                                    -0.000597
#  Standard deviation of the integrated profile                                       1.000000
#  Excess kurtosis of the integrated profile                                          0.011141
#  Skewness of the integrated profile                                                 0.007630
#  Mean of the DM-SNR curve                                                           0.006360
#  Standard deviation of the DM-SNR curve                                             0.011624
#  Excess kurtosis of the DM-SNR curve                                               -0.009918
#  Skewness of the DM-SNR curve                                                      -0.006380
#
#                                                 Excess kurtosis of the integrated profile  \
#  Mean of the integrated profile                                                 -0.039351
#  Standard deviation of the integrated profile                                    0.011141
#  Excess kurtosis of the integrated profile                                       1.000000
#  Skewness of the integrated profile                                              0.945729
#  Mean of the DM-SNR curve                                                        0.414368
#  Standard deviation of the DM-SNR curve                                          0.432880
#  Excess kurtosis of the DM-SNR curve                                            -0.341209
#  Skewness of the DM-SNR curve                                                   -0.214491
#
#                                                 Skewness of the integrated profile  \
#  Mean of the integrated profile                                          -0.031990
#  Standard deviation of the integrated profile                             0.007630
#  Excess kurtosis of the integrated profile                                0.945729
#  Skewness of the integrated profile                                       1.000000
#  Mean of the DM-SNR curve                                                 0.412056
#  Standard deviation of the DM-SNR curve                                   0.415140
#  Excess kurtosis of the DM-SNR curve                                     -0.328843
#  Skewness of the DM-SNR curve                                            -0.204782
#
#                                                 Mean of the DM-SNR curve  \
#  Mean of the integrated profile                                -0.013739
#  Standard deviation of the integrated profile                   0.006360
#  Excess kurtosis of the integrated profile                      0.414368
#  Skewness of the integrated profile                             0.412056
#  Mean of the DM-SNR curve                                       1.000000
#  Standard deviation of the DM-SNR curve                         0.796555
#  Excess kurtosis of the DM-SNR curve                           -0.615971
#  Skewness of the DM-SNR curve                                  -0.354269
#
#                                                 Standard deviation of the DM-SNR curve  \
#  Mean of the integrated profile                                              -0.010734
#  Standard deviation of the integrated profile                                 0.011624
#  Excess kurtosis of the integrated profile                                    0.432880
#  Skewness of the integrated profile                                           0.415140
#  Mean of the DM-SNR curve                                                     0.796555
#  Standard deviation of the DM-SNR curve                                       1.000000
#  Excess kurtosis of the DM-SNR curve                                         -0.809786
#  Skewness of the DM-SNR curve                                                -0.575800
#
#                                                 Excess kurtosis of the DM-SNR curve  \
#  Mean of the integrated profile                                            0.009607
#  Standard deviation of the integrated profile                             -0.009918
#  Excess kurtosis of the integrated profile                                -0.341209
#  Skewness of the integrated profile                                       -0.328843
#  Mean of the DM-SNR curve                                                 -0.615971
#  Standard deviation of the DM-SNR curve                                   -0.809786
#  Excess kurtosis of the DM-SNR curve                                       1.000000
#  Skewness of the DM-SNR curve                                              0.923743
#
#                                                 Skewness of the DM-SNR curve
#  Mean of the integrated profile                                     0.008601
#  Standard deviation of the integrated profile                      -0.006380
#  Excess kurtosis of the integrated profile                         -0.214491
#  Skewness of the integrated profile                                -0.204782
#  Mean of the DM-SNR curve                                          -0.354269
#  Standard deviation of the DM-SNR curve                            -0.575800
#  Excess kurtosis of the DM-SNR curve                                0.923743
#  Skewness of the DM-SNR curve                                       1.000000

# %%
data.var()
# Out:
#  Mean of the integrated profile                  3.913154e+08
#  Standard deviation of the integrated profile    5.844042e+04
#  Excess kurtosis of the integrated profile       1.132181e+00
#  Skewness of the integrated profile              3.804315e+01
#  Mean of the DM-SNR curve                        8.686517e+02
#  Standard deviation of the DM-SNR curve          3.791032e+02
#  Excess kurtosis of the DM-SNR curve             2.030486e+01
#  Skewness of the DM-SNR curve                    1.134535e+04
# dtype: float64

# %% [markdown]
# ## Pré-processamento
#
# Normalização

# %%
x = data.values; #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler();
x_scaled = min_max_scaler.fit_transform(x);
data = pd.DataFrame(x_scaled, columns=data.columns);
data.head()
# Out:
#     Mean of the integrated profile  \
# 0                         0.000776
# 1                         0.000557
# 2                         0.000560
# 3                         0.000754
# 4                         0.000478
#
#     Standard deviation of the integrated profile  \
# 0                                       0.000956
# 1                                       0.001054
# 2                                       0.000450
# 3                                       0.001002
# 4                                       0.000492
#
#     Excess kurtosis of the integrated profile  \
# 0                                    0.165043
# 1                                    0.235415
# 2                                    0.221138
# 3                                    0.181750
# 4                                    0.249044
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                             0.015627                   0.013382
# 1                             0.018268                   0.006560
# 2                             0.040677                   0.013030
# 3                             0.016534                   0.015368
# 4                             0.041712                   0.004327
#
#     Standard deviation of the DM-SNR curve  \
# 0                                 0.113681
# 1                                 0.072524
# 2                                 0.139188
# 3                                 0.131583
# 4                                 0.039684
#
#     Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve
# 0                              0.294986                       0.063890
# 1                              0.364015                       0.108443
# 2                              0.288624                       0.054610
# 3                              0.266348                       0.046581
# 4                              0.462029                       0.213369

# %%
data.var()
# Out:
#  Mean of the integrated profile                  0.012982
#  Standard deviation of the integrated profile    0.000056
#  Excess kurtosis of the integrated profile       0.011446
#  Skewness of the integrated profile              0.007788
#  Mean of the DM-SNR curve                        0.017440
#  Standard deviation of the DM-SNR curve          0.035546
#  Excess kurtosis of the DM-SNR curve             0.014302
#  Skewness of the DM-SNR curve                    0.007972
# dtype: float64

# %%
### np.min(data.iloc[:,5].values)

data[data.iloc[:,4] == 0]
# data.iloc[5043]
# Out:
#         Mean of the integrated profile  \
# 6234                          0.000725
# 9524                          0.000765
# 11975                         0.000529
# 12081                         0.000590
#
#         Standard deviation of the integrated profile  \
# 6234                                        0.000788
# 9524                                        0.000617
# 11975                                       0.000694
# 12081                                       0.001451
#
#         Excess kurtosis of the integrated profile  \
# 6234                                     0.189600
# 9524                                     0.171771
# 11975                                    0.213221
# 12081                                    0.245515
#
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 6234                              0.026857                        0.0
# 9524                              0.030666                        0.0
# 11975                             0.027743                        0.0
# 12081                             0.011030                        0.0
#
#         Standard deviation of the DM-SNR curve  \
# 6234                                       0.0
# 9524                                       0.0
# 11975                                      0.0
# 12081                                      0.0
#
#         Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve
# 6234                                    1.0                            1.0
# 9524                                    1.0                            1.0
# 11975                                   1.0                            1.0
# 12081                                   1.0                            1.0
